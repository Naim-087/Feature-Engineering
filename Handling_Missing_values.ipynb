# %% [markdown]
# # SetUp & LoadDataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/sample_data/pneumonia_dataset.csv')
df
# Out:
#     PatientID Gender  Age   Cough     Fever Shortness_of_breath Chest_pain  \
# 0    PNEU4091      M    3  Bloody      High                Mild       Mild
# 1    PNEU6231      M    3     Dry       NaN                 NaN        NaN
# 2    PNEU6486      M    3     Dry       NaN                 NaN        NaN
# 3    PNEU7601      F    3     NaN       Low              Severe        NaN
# 4    PNEU8471      F    3     NaN      High            Moderate     Severe
# ..        ...    ...  ...     ...       ...                 ...        ...
# 705   PNEU360      F   90     Wet       NaN            Moderate   Moderate
# 706  PNEU4391      F   90     Dry      High            Moderate   Moderate
# 707  PNEU6720      M   90     Dry       NaN                 NaN        NaN
# 708  PNEU9254      M   90     NaN  Moderate              Severe     Severe
# 709  PNEU9397      F   90     NaN       NaN                Mild       Mild
#
#       Fatigue Confusion Oxygen_saturation Crackles Xray WBC_count  \
# ...

# %% [markdown]
# # 1.Basic Informations

# %% [markdown]
# **About rows,columns, dataTypes**

# %% [markdown]
# ## shape

# %%
print("Shape : ",df.shape)
# Out:
# Shape :  (710, 16)

# %% [markdown]
# ## information

# %%
print("Informarions : ",df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 710 entries, 0 to 709
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PatientID            710 non-null    object
#  1   Gender               710 non-null    object
#  2   Age                  710 non-null    int64
#  3   Cough                398 non-null    object
#  4   Fever                400 non-null    object
#  5   Shortness_of_breath  393 non-null    object
#  6   Chest_pain           367 non-null    object
#  7   Fatigue              605 non-null    object
#  8   Confusion            710 non-null    object
#  9   Oxygen_saturation    710 non-null    object
#  10  Crackles             710 non-null    object
#  11  Xray                 710 non-null    object
#  12  WBC_count            710 non-null    object
#  13  Sputum_color         710 non-null    object
#  14  Temperature          710 non-null    float64
# ...

# %% [markdown]
# ## unique

# %%
df.nunique()
# Out:
# PatientID              687
# Gender                   2
# Age                     88
# Cough                    3
# Fever                    3
# Shortness_of_breath      3
# Chest_pain               3
# Fatigue                  3
# Confusion                3
# Oxygen_saturation       17
# Crackles                 2
# Xray                     5
# WBC_count               11
# Sputum_color             5
# Temperature             54
# Diagnosis                2
# dtype: int64

# %%
df.columns
# Out:
# Index(['PatientID', 'Gender', 'Age', 'Cough', 'Fever', 'Shortness_of_breath',
#        'Chest_pain', 'Fatigue', 'Confusion', 'Oxygen_saturation', 'Crackles',
#        'Xray', 'WBC_count', 'Sputum_color', 'Temperature', 'Diagnosis'],
#       dtype='object')

# %% [markdown]
# > Insight: At this point you should know basic things like how many rows and columns you have, what each column type is, and whether there are any suspicious values such as negative ages or impossible measurements.

# %% [markdown]
# # 2.Handling Missing Values

# %%
df.isna().sum()
# Out:
# PatientID                0
# Gender                   0
# Age                      0
# Cough                  312
# Fever                  310
# Shortness_of_breath    317
# Chest_pain             343
# Fatigue                105
# Confusion                0
# Oxygen_saturation        0
# Crackles                 0
# Xray                     0
# WBC_count                0
# Sputum_color             0
# Temperature              0
# Diagnosis                0
# dtype: int64

# %%
missing_cols = ['Cough', 'Fever', 'Shortness_of_breath', 'Chest_pain', 'Fatigue']
missing_cols
# Out:
# ['Cough', 'Fever', 'Shortness_of_breath', 'Chest_pain', 'Fatigue']

# %% [markdown]
# ## Import libraries

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
#Numerical Pipeline

#There is no missing value in numeric column so
#Numeric pipeline no needed.

# %%
from sklearn import preprocessing
# Catg pipeline

cat_pipeline = Pipeline([
    ('imputer',SimpleImputer(strategy='most_frequent'))
])

# %%
#column Transformation

preprocessor = ColumnTransformer(
    transformers=[
        ('ordinal_col',cat_pipeline,missing_cols)
    ],
    remainder='passthrough'
)

# %%
preprocessor.set_output(transform='pandas')
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('ordinal_col',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent'))]),
#                                  ['Cough', 'Fever', 'Shortness_of_breath',
#                                   'Chest_pain', 'Fatigue'])])

# %%
df_clean = preprocessor.fit_transform(df)
df_clean
# Out:
#     ordinal_col__Cough ordinal_col__Fever ordinal_col__Shortness_of_breath  \
# 0               Bloody               High                             Mild
# 1                  Dry                Low                             Mild
# 2                  Dry                Low                             Mild
# 3                  Dry                Low                           Severe
# 4                  Dry               High                         Moderate
# ..                 ...                ...                              ...
# 705                Wet                Low                         Moderate
# 706                Dry               High                         Moderate
# 707                Dry                Low                             Mild
# 708                Dry           Moderate                           Severe
# 709                Dry                Low                             Mild
#
# ...

# %%
df_clean.isna().sum()
# Out:
# ordinal_col__Cough                  0
# ordinal_col__Fever                  0
# ordinal_col__Shortness_of_breath    0
# ordinal_col__Chest_pain             0
# ordinal_col__Fatigue                0
# remainder__PatientID                0
# remainder__Gender                   0
# remainder__Age                      0
# remainder__Confusion                0
# remainder__Oxygen_saturation        0
# remainder__Crackles                 0
# remainder__Xray                     0
# remainder__WBC_count                0
# remainder__Sputum_color             0
# remainder__Temperature              0
# remainder__Diagnosis                0
# dtype: int64
